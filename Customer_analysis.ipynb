# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Project\Final project\Customer_Data.csv")

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                      53.0       Kentucky    L       Gray  Winter
# 1                      64.0          Maine    L     Maroon  Winter
# ...

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                   53.0
# 1            2   19   Male        Sweater  Clothing                   64.0
# 2            3   50   Male          Jeans  Clothing                   73.0
# 3            4   21   Male        Sandals  Footwear                   90.0
# 4            5   45   Male         Blouse  Clothing                   49.0
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.tail()
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)    Location Size      Color  Season  \
# 3895                   28.0    Virginia    L  Turquoise  Summer
# 3896                   49.0        Iowa    L      White  Spring
# 3897                   33.0  New Jersey    L      Green  Spring
# 3898                   77.0   Minnesota    S      Brown  Summer
# 3899                   81.0  California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 3895            4.2                  No  2-Day Shipping               No
# 3896            4.5                  No    Store Pickup               No
# ...

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3899 non-null   object
#  3   Item Purchased          3899 non-null   object
#  4   Category                3899 non-null   object
#  5   Purchase Amount (USD)   3898 non-null   float64
#  6   Location                3897 non-null   object
#  7   Size                    3899 non-null   object
#  8   Color                   3899 non-null   object
#  9   Season                  3898 non-null   object
#  10  Review Rating           3862 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3899 non-null   object
#  13  Discount Applied        3899 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3898.000000    3862.000000
# mean   1950.500000    44.068462              59.768343       3.749845
# std    1125.977353    15.207589              23.682919       0.716945
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3899.000000
# mean            25.347012
# std             14.446212
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     1
# Item Purchased             1
# Category                   1
# Purchase Amount (USD)      2
# Location                   3
# Size                       1
# Color                      1
# Season                     2
# Review Rating             38
# Subscription Status        0
# Shipping Type              1
# Discount Applied           1
# Promo Code Used            2
# Previous Purchases         1
# Payment Method             2
# Frequency of Purchases     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3899 non-null   object
#  3   Item Purchased          3899 non-null   object
#  4   Category                3899 non-null   object
#  5   Purchase Amount (USD)   3898 non-null   float64
#  6   Location                3897 non-null   object
#  7   Size                    3899 non-null   object
#  8   Color                   3899 non-null   object
#  9   Season                  3898 non-null   object
#  10  Review Rating           3862 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3899 non-null   object
#  13  Discount Applied        3899 non-null   object
# ...

# %%
df.columns = df.columns.str.lower().str.replace(" ","_").str.replace("(","").str.replace(")","")

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_usd', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %%
df['gender'].fillna(df['gender'].mode()[0], inplace=True)

df['item_purchased'].fillna(df['item_purchased'].mode()[0], inplace=True)

df['category'].fillna(df['category'].mode()[0], inplace=True)

df['location'].fillna(df['location'].mode()[0], inplace=True)

df['size'].fillna(df['size'].mode()[0], inplace=True)

df['color'].fillna(df['color'].mode()[0], inplace=True)

df['season'].fillna(df['season'].mode()[0], inplace=True)

df['shipping_type'].fillna(df['shipping_type'].mode()[0], inplace=True)

df['discount_applied'].fillna(df['discount_applied'].mode()[0], inplace=True)

df['promo_code_used'].fillna(df['promo_code_used'].mode()[0], inplace=True)

df['payment_method'].fillna(df['payment_method'].mode()[0], inplace=True)


df['purchase_amount_usd'].fillna(df['purchase_amount_usd'].mean(), inplace=True)

df['review_rating'].fillna(df['review_rating'].mean(), inplace=True)

df['previous_purchases'].fillna(df['previous_purchases'].mean(), inplace=True)
# Out:
# C:\Users\White__MC\AppData\Local\Temp\ipykernel_94472\599078182.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].fillna(df['gender'].mode()[0], inplace=True)
# C:\Users\White__MC\AppData\Local\Temp\ipykernel_94472\599078182.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# customer_id               0
# age                       0
# gender                    0
# item_purchased            0
# category                  0
# purchase_amount_usd       0
# location                  0
# size                      0
# color                     0
# season                    0
# review_rating             0
# subscription_status       0
# shipping_type             0
# discount_applied          0
# promo_code_used           0
# previous_purchases        0
# payment_method            0
# frequency_of_purchases    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# customer_id                 int64
# age                         int64
# gender                     object
# item_purchased             object
# category                   object
# purchase_amount_usd       float64
# location                   object
# size                       object
# color                      object
# season                     object
# review_rating             float64
# subscription_status        object
# shipping_type              object
# discount_applied           object
# promo_code_used            object
# previous_purchases        float64
# payment_method             object
# frequency_of_purchases     object
# dtype: object

# %%
df[df["purchase_amount_usd"]<0]
# Out:
# Empty DataFrame
# Columns: [customer_id, age, gender, item_purchased, category, purchase_amount_usd, location, size, color, season, review_rating, subscription_status, shipping_type, discount_applied, promo_code_used, previous_purchases, payment_method, frequency_of_purchases]
# Index: []

# %%
df["age"].describe()
# Out:
# count    3900.000000
# mean       44.068462
# std        15.207589
# min        18.000000
# 25%        31.000000
# 50%        44.000000
# 75%        57.000000
# max        70.000000
# Name: age, dtype: float64

# %%
df.to_csv("D:\Project\Final project\Customer Project Data\Outputs\customer_data_analyis.csv", index = False)

# %%
df["gender"].value_counts().plot(kind = 'bar')

plt.title('Gender_Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')

plt.show()

# %%
df['category'].value_counts().plot(kind = 'bar')

plt.title('Category Distribution')
plt.xlabel('category')
plt.ylabel('Counts')

plt.xticks(rotation = 45)
plt.show()

# %%
df['season'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%')

plt.title('season-Wise Purchases')

plt.show()

# %%
df['payment_method'].value_counts().plot(kind = 'bar')

plt.title('Payment Method Usage')
plt.xlabel('Payment Method')
plt.ylabel('Count')

plt.xticks(rotation = 45)

plt.show()

# %%
plt.hist(df['purchase_amount_usd'])

plt.title("Purchase Amount Distribution")
plt.xlabel('Purchase Amount')
plt.ylabel('Frequency')

plt.show()

# %%
df['subscription_status'].value_counts().plot(kind='pie', autopct='%1.1f%%')

plt.title('Subscription Status')

plt.show()

# %%
df.groupby('gender')['purchase_amount_usd'].mean().plot(kind='bar')

plt.title('Average Purchase Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Purchase')

plt.show()

# %%
df['location'].value_counts().head(10).plot(kind='bar')

plt.title('Top 10 Customer Locations')
plt.xlabel('Location')
plt.ylabel('Customers')

plt.xticks(rotation=45)

plt.show()

# %%
correlation = df[['age', 'purchase_amount_usd', 'review_rating', 'previous_purchases']].corr()

print(correlation)
# Out:
#                           age  purchase_amount_usd  review_rating  \
# age                  1.000000            -0.010586      -0.024270
# purchase_amount_usd -0.010586             1.000000       0.028725
# review_rating       -0.024270             0.028725       1.000000
# previous_purchases   0.040701             0.008335       0.003725
#
#                      previous_purchases
# age                            0.040701
# purchase_amount_usd            0.008335
# review_rating                  0.003725
# previous_purchases             1.000000

# %%
sns.heatmap(correlation, annot=True)

plt.title('Correlation Heatmap')

plt.show()
